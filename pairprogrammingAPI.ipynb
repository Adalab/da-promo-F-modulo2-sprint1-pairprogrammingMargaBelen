# %%
import requests
import pandas as pd
import re

#url =f'https://apidatos.ree.es/es/datos'
#url = 'https://apidatos.ree.es/es/datos/balance/balance-electrico?start_date=2019-01-01T00:00&end_date=2019-01-31T23:59&time_trunc=day'
#url = 'https://apidatos.ree.es/es/datos/generacion/evolucion-renovable-no-renovable?start_date=2011-01-01T00:00&end_date=2011-12-31T23:59&time_trunc=month'
url = 'https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2011-01-01T00:00&end_date=2011-12-31T23:59&time_trunc=month'

def llamar_api(url):

    llamada = requests.get(url)  

    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")  

    if llamada.status_code != 200:  
        print(f"El motivo por el que la llamada falló es {llamada.reason}")  
    else:
        return llamada.json()

# %%
json_energia= llamar_api(url)
json_energia.keys()
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200
# dict_keys(['data', 'included'])

# %%
json_energia['data']
# Out:
# {'type': 'Generación por tecnología',
#  'id': 'gen1',
#  'attributes': {'title': 'Generación por tecnología',
#   'last-update': '2019-06-12T15:32:24.000+02:00',
#   'description': None},
#  'meta': {'cache-control': {'cache': 'HIT',
#    'expireAt': '2023-11-24T07:07:31'}}}

# %%
json_energia['included']
#type(json_energia['included'])
# Out:
# [{'type': 'Hidráulica',
#   'id': '10288',
#   'groupId': '1',
#   'attributes': {'title': 'Hidráulica',
#    'description': None,
#    'color': '#0090d1',
#    'type': 'Renovable',
#    'magnitude': None,
#    'composite': False,
#    'last-update': '2019-06-12T15:32:24.000+02:00',
#    'values': [{'value': 5119512.38,
#      'percentage': 0.19757364151478785,
#      'datetime': '2011-01-01T00:00:00.000+01:00'},
#     {'value': 2998051.279,
#      'percentage': 0.12956959110916957,
#      'datetime': '2011-02-01T00:00:00.000+01:00'},
#     {'value': 3910363.276,
#      'percentage': 0.15594663753166463,
#      'datetime': '2011-03-01T00:00:00.000+01:00'},
#     {'value': 3537937.995,
#      'percentage': 0.16314748356694456,
#      'datetime': '2011-04-01T00:00:00.000+02:00'},
#     {'value': 2797500.027,
#      'percentage': 0.1279110558374734,
#      'datetime': '2011-05-01T00:00:00.000+02:00'},
#     {'value': 2070305.344,
#      'percentage': 0.09182271836090777,
# ...

# %%
len(json_energia['included'])
# Out:
# 17

# %%
tipo_energia = json_energia['included'][0]['type']
for x in tipo_energia:
    Energia= tipo_energia['included'][0]['type']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vc/6zzvx8k5237dtyhf94hsl1580000gp/T/ipykernel_53185/3674990475.py in <module>
#       1 tipo_energia = json_energia['included'][0]['type']
#       2 for x in tipo_energia:
# ----> 3     Energia= tipo_energia['included'][0]['type']
#
# TypeError: string indices must be integers

# %%
json_energia['included'][1].keys()
#json_energia['included'][1]['attributes'].keys()
# Out:
# dict_keys(['title', 'description', 'color', 'type', 'magnitude', 'composite', 'last-update', 'values'])

# %%
#var_test= json_energia['included'][0]['type']
var_test= json_energia['included']
type(var_test)

#for x in var_test:
#    print(x)
# Out:
# list
